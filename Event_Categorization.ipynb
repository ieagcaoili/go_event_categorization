# %% [markdown]
# # Event Categorization
#
# Below is the result of analyzing a list of arbitrary third-party events, and categorizing them into specific activities. Although the instruction focused on just the Eventbrite JSON file, I also looked at the Ticket Master JSON file for comparison.
#
# ## Eventbrite Classification
#
# For this exercise, it seemed more effective to explore the events data first, and then make decisions on the list of human activities immediately after.

# %%
# import numpy as np
import pandas as pd
import json

# open, load, and inspect the dict from the json file
eb_json = open('datasets/eb-response-page1.json')
eb_dict = json.load(eb_json)
eb_dict.keys()

# eb_dict['pagination']
# eb_dict['location']
# Out:
# dict_keys(['pagination', 'events', 'location'])

# %% [markdown]
# After navigating the dictionaries inside `eb_dict`, I discovered that all relevant data can be found in `events`.

# %%
# create df for data cleaning
eb_events_raw = pd.DataFrame(eb_dict['events'])
eb_events_raw.head(2).T
# Out:
#                                                                                   0  \
# name                              {'text': 'The 4 Shifts to Lifelong Health, End...
# description                       {'text': '4 Powerful Shifts to Lifelong Health...
# id                                                                      81156743003
# url                               https://www.eventbrite.com/e/the-4-shifts-to-l...
# start                             {'timezone': 'America/Los_Angeles', 'local': '...
# end                               {'timezone': 'America/Los_Angeles', 'local': '...
# organization_id                                                        304101319856
# created                                                        2019-11-10T05:59:40Z
# changed                                                        2019-11-10T06:00:24Z
# published                                                      2019-11-10T06:00:24Z
# capacity                                                                       None
# capacity_is_custom                                                             None
# status                                                                         live
# currency                                                                        USD
# listed                                                                         True
# shareable                                                                     False
# online_event                                                                  False
# tx_time_limit                                                                   480
# hide_start_date                                                               False
# hide_end_date                                                                 False
# locale                                                                        en_US
# is_locked                                                                     False
# privacy_setting                                                            unlocked
# is_series                                                                     False
# is_series_parent                                                              False
# inventory_type                                                              limited
# is_reserved_seating                                                           False
# show_pick_a_seat                                                              False
# show_seatmap_thumbnail                                                        False
# show_colors_in_seatmap_thumbnail                                              False
# source                                                                       coyote
# is_free                                                                        True
# version                                                                       3.7.0
# summary                           4 Powerful Shifts to Lifelong Health, Endless ...
# logo_id                                                                    78274523
# organizer_id                                                            27496861047
# venue_id                                                                   42323101
# category_id                                                                     107
# subcategory_id                                                                 None
# format_id                                                                         9
# resource_uri                      https://www.eventbriteapi.com/v3/events/811567...
# is_externally_ticketed                                                        False
# logo                              {'crop_mask': {'top_left': {'x': 0, 'y': 0}, '...
# series_id                                                                       NaN
#
#                                                                                   1
# name                              {'text': 'Easy Access to Business Lines of Cre...
# description                       {'text': 'Raising Capital for My Business
# Fast...
# id                                                                      70394157821
# url                               https://www.eventbrite.com/e/easy-access-to-bu...
# start                             {'timezone': 'America/Los_Angeles', 'local': '...
# end                               {'timezone': 'America/Los_Angeles', 'local': '...
# organization_id                                                        308256707370
# created                                                        2019-08-24T19:57:54Z
# changed                                                        2019-08-24T19:57:59Z
# published                                                      2019-08-24T19:57:58Z
# capacity                                                                       None
# capacity_is_custom                                                             None
# status                                                                         live
# currency                                                                        USD
# listed                                                                         True
# shareable                                                                      True
# online_event                                                                  False
# tx_time_limit                                                                   480
# hide_start_date                                                               False
# hide_end_date                                                                 False
# locale                                                                        en_US
# is_locked                                                                     False
# privacy_setting                                                            unlocked
# is_series                                                                      True
# is_series_parent                                                              False
# inventory_type                                                              limited
# is_reserved_seating                                                           False
# show_pick_a_seat                                                              False
# show_seatmap_thumbnail                                                        False
# show_colors_in_seatmap_thumbnail                                              False
# source                                                                   create_2.0
# is_free                                                                        True
# version                                                                       3.0.0
# summary                           Raising Capital for My Business\nFast Unsecure...
# logo_id                                                                    69784957
# organizer_id                                                            21057337727
# venue_id                                                                   36884067
# category_id                                                                     101
# subcategory_id                                                                 1001
# format_id                                                                         9
# resource_uri                      https://www.eventbriteapi.com/v3/events/703941...
# is_externally_ticketed                                                        False
# logo                              {'crop_mask': {'top_left': {'x': 0, 'y': 41}, ...
# series_id                                                               70394067551

# %% [markdown]
# I explored `name`, `description`, `start`, and `end`, just in case they contained information that could help in the categorization. I ended up getting just the `text` values for `name` and `description`, and the `local` values from `

# %%
# eb_dict_cols = ['name', 'description', 'start', 'end']

# for e in eb_dict_cols:
#     print('Sample entries in "{}":'.format(e))
#     for event in eb_events_raw[e][:2]:
#         print(event)
#     print('\n')

# eb_events_raw['pacific_time_start'] = eb_events_raw['start'].map(lambda x: x['local'])
# eb_events_raw['pacific_time_end'] = eb_events_raw['end'].map(lambda x: x['local'])

# %%
eb_events_raw['name_text'] = eb_events_raw['name'].map(lambda x: x['text'])
eb_events_raw['description_text'] = eb_events_raw['description'].map(lambda x: x['text'])

# %%
eb_events_raw['name_text'].head()
# Out:
# 0    The 4 Shifts to Lifelong Health, Endless Energ...
# 1    Easy Access to Business Lines of Credit - Port...
# 2          Where Can I Get Business Funding - Portland
# 3          Where Can I Get Business Funding - Portland
# 4    A Guide to Korean BBQ - Team Building by Cozym...
# Name: name_text, dtype: object

# %%
eb_events_raw['description_text'].head()
# Out:
# 0    4 Powerful Shifts to Lifelong Health, Endless ...
# 1    Raising Capital for My Business\nFast Unsecure...
# 2    Raising Capital for My Business\nUnderstanding...
# 3    Raising Capital for My Business\nUnderstanding...
# 4    Book a unique team building event centered aro...
# Name: description_text, dtype: object

# %% [markdown]
# I created a smaller dataframe `eb_events` that only contained the columns that were essential to complete the task at hand.

# %%
# identify relevant columns to retain
eb_cols = ['id',
           'name_text',
           'description_text',
           'summary',
           'url',
           'category_id',
           'subcategory_id'
          ]

# create new df with streamlined data
eb_events = eb_events_raw[eb_cols]
eb_events.head()
# Out:
#             id                                          name_text  \
# 0  81156743003  The 4 Shifts to Lifelong Health, Endless Energ...
# 1  70394157821  Easy Access to Business Lines of Credit - Port...
# 2  70311727269        Where Can I Get Business Funding - Portland
# 3  70309033211        Where Can I Get Business Funding - Portland
# 4  81376997791  A Guide to Korean BBQ - Team Building by Cozym...
#
#                                     description_text  \
# 0  4 Powerful Shifts to Lifelong Health, Endless ...
# 1  Raising Capital for My Business\nFast Unsecure...
# 2  Raising Capital for My Business\nUnderstanding...
# 3  Raising Capital for My Business\nUnderstanding...
# 4  Book a unique team building event centered aro...
#
#                                              summary  \
# 0  4 Powerful Shifts to Lifelong Health, Endless ...
# 1  Raising Capital for My Business\nFast Unsecure...
# 2  Raising Capital for My Business\nUnderstanding...
# 3  Raising Capital for My Business\nUnderstanding...
# 4  Book a unique team building event centered aro...
#
#                                                  url category_id  \
# 0  https://www.eventbrite.com/e/the-4-shifts-to-l...         107
# 1  https://www.eventbrite.com/e/easy-access-to-bu...         101
# 2  https://www.eventbrite.com/e/where-can-i-get-b...         101
# 3  https://www.eventbrite.com/e/where-can-i-get-b...         101
# 4  https://www.eventbrite.com/e/a-guide-to-korean...         110
#
#   subcategory_id
# 0           None
# 1           1001
# 2           1001
# 3           1001
# 4          10003

# %%
# eb_events[eb_events['category_id'] == '101']

eb_events['category_id'].value_counts()
# Out:
# 110    40
# 101     7
# 107     3
# Name: category_id, dtype: int64

# %% [markdown]
# It seemed like I could just leverage Eventbrite's own classification to complete the task. Here are the activities:
#
# - 101: Business Classes
# - 107: Health Classes
# - 110: Cooking Classes
#
# I created a dictionary for these key-value pairs, and created a new `eb_events` column called `category`. Since some of these events are actually the same classes in different time slots, I grabbed only the unique event names for the final output.

# %%
eb_cats = {'101': 'Business Classes',
           '107': 'Health Classes',
           '110': 'Cooking Classes'}

pd.options.mode.chained_assignment = None  # default='warn'
eb_events['category'] = eb_events['category_id'].apply(lambda x: eb_cats[x])
eb_events[['name_text', 'category', 'category_id', ]].drop_duplicates().sort_values(by='category_id')
# Out:
#                                             name_text          category  \
# 1   Easy Access to Business Lines of Credit - Port...  Business Classes
# 2         Where Can I Get Business Funding - Portland  Business Classes
# 41  CBD Health & Wellness Business Opportunity (Jo...  Business Classes
# 28  Real Estate Investing for Entrepreneurs - Port...  Business Classes
# 27  Learn To Do Real Estate in less time & make mo...  Business Classes
# 26             MINDSHOP™ | The Art of Lean Innovation  Business Classes
# 0   The 4 Shifts to Lifelong Health, Endless Energ...    Health Classes
# 42  Train Your Brain To Make More Money - 6 Critic...    Health Classes
# 25  Heal Your Binge Eating and Lifelong Dieting [F...    Health Classes
# 43    Vegan Comfort Food - Cooking Class by Cozymeal™   Cooking Classes
# 22  Mexican Fiesta Favorites - Team Building by Co...   Cooking Classes
# 21         Yasashi Sushi - Team Building by Cozymeal™   Cooking Classes
# 16  Traditional and Modern Japanese Desserts - Coo...   Cooking Classes
# 44  Intro to International Flavor - Cooking Class ...   Cooking Classes
# 13  Mastering French Macarons - Cooking Class by C...   Cooking Classes
# 10  Mastering Choux Pastry - Cooking Class by Cozy...   Cooking Classes
# 9   Journey Through Greece - Team Building by Cozy...   Cooking Classes
# 8   Authentic Mexican Fare - Team Building by Cozy...   Cooking Classes
# 7   Spicy Pork Belly Ramen - Cooking Class by Cozy...   Cooking Classes
# 6   A Traditional Valencian Feast - Cooking Class ...   Cooking Classes
# 5   Classic Indian Butter Chicken - Cooking Class ...   Cooking Classes
# 4   A Guide to Korean BBQ - Team Building by Cozym...   Cooking Classes
# 19  Simple and Stunning Italian - Team Building by...   Cooking Classes
# 48       Homemade Bagels - Cooking Class by Cozymeal™   Cooking Classes
#
#    category_id
# 1          101
# 2          101
# 41         101
# 28         101
# 27         101
# 26         101
# 0          107
# 42         107
# 25         107
# 43         110
# 22         110
# 21         110
# 16         110
# 44         110
# 13         110
# 10         110
# 9          110
# 8          110
# 7          110
# 6          110
# 5          110
# 4          110
# 19         110
# 48         110

# %% [markdown]
# To extend the scope of this classification, it might be necessary to leverage Eventbrite's own categorization, and maybe add a layer of specificity as necessary.
#
# # Ticket Master Classification
#
# In trying to think through how to best leverage existing data to categorize events, I also looked at Ticket Master's json file. My goal was to have an idea of their taxonomy, and pick up on some best practices. Below are some sample rows from the dataframe.

# %%
# open, load, and inspect the dict from the json file
tm_json = open('datasets/tm-response-page1.json')
tm_dict = json.load(tm_json)

tm_events_raw = pd.DataFrame(tm_dict['_embedded']['events'])
tm_events_raw.head(4).T
# Out:
#                                                                  0  \
# name                 Portland Trail Blazers vs. Los Angeles Lakers
# type                                                         event
# id                                                  vvG1HZ4YSAOKK5
# test                                                         False
# url              https://www.ticketmaster.com/portland-trail-bl...
# locale                                                       en-us
# images           [{'ratio': '3_2', 'url': 'https://s1.ticketm.n...
# sales            {'public': {'startDateTime': '2019-09-09T17:00...
# dates            {'start': {'localDate': '2019-12-06', 'localTi...
# classifications  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# promoter         {'id': '695', 'name': 'NBA REGULAR SEASON', 'd...
# promoters        [{'id': '695', 'name': 'NBA REGULAR SEASON', '...
# pleaseNote                              This event is Mobile Only.
# priceRanges      [{'type': 'standard', 'currency': 'USD', 'min'...
# products         [{'id': 'vvG1HZ4YM_O7A0', 'url': 'https://www....
# seatmap          {'staticUrl': 'https://s1.ticketm.net/tmimages...
# ticketLimit      {'info': 'The Trail Blazers reserve the right ...
# _links           {'self': {'href': '/discovery/v2/events/vvG1HZ...
# _embedded        {'venues': [{'name': 'Moda Center', 'type': 'v...
# info                                                           NaN
# outlets                                                        NaN
#
#                                                                  1  \
# name                 Portland Trail Blazers vs. Los Angeles Lakers
# type                                                         event
# id                                                  vvG1HZ4YSA-KK2
# test                                                         False
# url              https://www.ticketmaster.com/portland-trail-bl...
# locale                                                       en-us
# images           [{'ratio': '3_2', 'url': 'https://s1.ticketm.n...
# sales            {'public': {'startDateTime': '2019-09-09T17:00...
# dates            {'start': {'localDate': '2019-12-28', 'localTi...
# classifications  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# promoter         {'id': '695', 'name': 'NBA REGULAR SEASON', 'd...
# promoters        [{'id': '695', 'name': 'NBA REGULAR SEASON', '...
# pleaseNote                              This event is Mobile Only.
# priceRanges      [{'type': 'standard', 'currency': 'USD', 'min'...
# products         [{'id': 'vvG1HZ4YM_PfkG', 'url': 'https://www....
# seatmap          {'staticUrl': 'https://s1.ticketm.net/tmimages...
# ticketLimit      {'info': 'The Trail Blazers reserve the right ...
# _links           {'self': {'href': '/discovery/v2/events/vvG1HZ...
# _embedded        {'venues': [{'name': 'Moda Center', 'type': 'v...
# info                                                           NaN
# outlets                                                        NaN
#
#                                                                  2  \
# name                 Portland Trail Blazers vs. Washington Wizards
# type                                                         event
# id                                                  vvG1HZ4YSk8dpE
# test                                                         False
# url              https://www.ticketmaster.com/portland-trail-bl...
# locale                                                       en-us
# images           [{'ratio': '3_2', 'url': 'https://s1.ticketm.n...
# sales            {'public': {'startDateTime': '2019-09-09T17:00...
# dates            {'start': {'localDate': '2020-03-04', 'localTi...
# classifications  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# promoter         {'id': '695', 'name': 'NBA REGULAR SEASON', 'd...
# promoters        [{'id': '695', 'name': 'NBA REGULAR SEASON', '...
# pleaseNote                              This event is Mobile Only.
# priceRanges      [{'type': 'standard', 'currency': 'USD', 'min'...
# products         [{'id': 'vvG1HZ4YM_3f7A', 'url': 'https://www....
# seatmap          {'staticUrl': 'https://s1.ticketm.net/tmimages...
# ticketLimit      {'info': 'The Trail Blazers reserve the right ...
# _links           {'self': {'href': '/discovery/v2/events/vvG1HZ...
# _embedded        {'venues': [{'name': 'Moda Center', 'type': 'v...
# info                                                           NaN
# outlets                                                        NaN
#
#                                                                  3
# name             Oregon Ducks Men's Basketball vs. UCLA Bruins ...
# type                                                         event
# id                                                  vvG1HZ4SlVpy61
# test                                                         False
# url              https://www.ticketmaster.com/oregon-ducks-mens...
# locale                                                       en-us
# images           [{'ratio': '16_9', 'url': 'https://s1.ticketm....
# sales            {'public': {'startDateTime': '2019-10-14T15:30...
# dates            {'start': {'localDate': '2020-01-26', 'localTi...
# classifications  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# promoter                                                       NaN
# promoters                                                      NaN
# pleaseNote       Please note, the view of some video boards may...
# priceRanges      [{'type': 'standard', 'currency': 'USD', 'min'...
# products                                                       NaN
# seatmap          {'staticUrl': 'https://s1.ticketm.net/tmimages...
# ticketLimit      {'info': 'There is an overall 8 ticket limit f...
# _links           {'self': {'href': '/discovery/v2/events/vvG1HZ...
# _embedded        {'venues': [{'name': 'Matthew Knight Arena', '...
# info                                                           NaN
# outlets                                                        NaN

# %% [markdown]
# The sample data suggests that there are more datapoints that need to be sussed out from columns that contain dictionaries. The column `classifications` contain ways of categorizing, with keys like `segment`, `genre`, `subGenre`, `type`, `subType` and `family`. There are columns with `Undefined` values, so I used `Unknown` instead to fill out null values.

# %%
cls = tm_events_raw.classifications
cls_cols = ['name', 'segment', 'genre', 'subGenre', 'type', 'subType', 'family']
col_list = []

for col in cls_cols[1:]:
    for i in range(cls.shape[0]):
        try: 
            col_list.append(cls[i][0][col]['name'])
        except:
            col_list.append('Unknown')
            
    tm_events_raw[col] = col_list
    col_list.clear()

# %%
tm_events_raw[cls_cols].head()
# Out:
#                                                 name segment       genre  \
# 0      Portland Trail Blazers vs. Los Angeles Lakers  Sports  Basketball
# 1      Portland Trail Blazers vs. Los Angeles Lakers  Sports  Basketball
# 2      Portland Trail Blazers vs. Washington Wizards  Sports  Basketball
# 3  Oregon Ducks Men's Basketball vs. UCLA Bruins ...  Sports  Basketball
# 4           Portland Trail Blazers vs. Chicago Bulls  Sports  Basketball
#
#   subGenre   type subType   family
# 0      NBA  Group    Team  Unknown
# 1      NBA  Group    Team  Unknown
# 2      NBA  Group    Team  Unknown
# 3  College  Group    Team  Unknown
# 4      NBA  Group    Team  Unknown

# %% [markdown]
# Adapting a multi-level approach to categorizing seems more beneficial in the long-term, so adapting a similar strategy might be a good idea.
